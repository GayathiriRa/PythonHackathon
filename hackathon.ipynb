# %% [markdown]
# #                           PYTHON PIRATES
# # WELCOME TO OUR HACKATHON
# # ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## IMPORT ALL LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
from datetime import datetime
from datetime import date
import re

# %% [markdown]
# # #Question 1-20

# %%
raw_data=pd.read_excel(r'HospitalDatabase.xlsx')
raw_data
# Out:
#      PatientID FirstName  LastName             DateOfBirth Gender  \
# 0            1     Lanni       Sue 1960-01-01 00:00:00.000   Male
# 1            2       Far     Myers 1985-11-15 02:08:42.090   Male
# 2            3   Devlin    Michael 1976-04-15 02:52:09.762   Male
# 3            4   Carmine     Texas 1968-10-15 03:32:13.635   Male
# 4            5     Tann       Bama 1962-05-01 19:12:58.950   Male
# ..         ...       ...       ...                     ...    ...
# 940        941       Wat   Fideler 1986-05-26 00:01:19.761   Male
# 941        942    Wandie  Baythrop 1970-06-10 21:41:03.814   Male
# 942        943   Diahann   Smeeton 1983-01-08 21:49:27.884   Male
# 943        944  Panchito   Sharple 1963-06-05 07:57:05.569   Male
# 944        945     Walsh    Calvie 1972-08-06 03:40:03.454   Male
#
#                        Race Language
# 0                     White  English
# 1                     White  English
# 2                     White  English
# ...

# %%
palette=sns.color_palette("flare", as_cmap=True)

# %% [markdown]
# ### Q.no:1  Make a pair plot on Readmission Registry table & do u see any correlation between columns values

# %%
raw_data=pd.read_excel(r'HospitalDatabase.xlsx',3)

raw_data.columns
g=sns.pairplot(raw_data,palette='flare')
g=sns.pairplot(raw_data[['PatientID','ExpectedLOS','ExpectedMortality']],diag_kind="kde",plot_kws={'color':'pink'})

# %% [markdown]
# ### Q.no: 2 Using iloc, retrieve the firstname and lastname of patients between indices 101 and 200

# %%
raw_data.iloc[101:201,1:3]
# Out:
#      PatientID AdmissionDate
# 101         96    2018-01-06
# 102         97    2018-01-06
# 103         98    2018-01-06
# 104         99    2018-01-06
# 105        100    2018-01-07
# ..         ...           ...
# 196        193    2018-01-15
# 197        194    2018-01-15
# 198        195    2018-01-15
# 199        196    2018-01-15
# 200        197    2018-01-15
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Q.no: 3 Create a figure object called fig using plt.figure() .
# #### Use add_axes to add an axis to the figure canvas at [0,0,1,1].
# #### call this new axis ax. Plot (x ,y) on that axes and set the labels and titles .

# %%
# Let's create a figure with size 8 x 6 inches 
fig = plt.figure(figsize=(6, 4), facecolor='yellow')

# Let's add three Axes instances:
ax = fig.add_axes((0, 0, 1, 1), facecolor='pink')


# Let's define the x and y values.
x = np.linspace(-10, 10, 100)
#Linear expression
y = 2*x+1

# Let's plot the  function.
ax.plot(x, y, color='black')

#Assign the label
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("My take on Q.no: 3")
plt.show()

# %% [markdown]
# #### Q.no : 5 Display full name of patients who are born in 1986

# %%
df=pd.read_excel(r'HospitalDatabase.xlsx')

df['Full_Name']=df['FirstName']+df['LastName']
# Condition
filtered_df = df.loc[(df['DateOfBirth'] >= '1986-01-01')
                     & (df['DateOfBirth'] < '1986-12-31')]
filtered_df
# Out:
#      PatientID   FirstName    LastName             DateOfBirth  Gender  \
# 23          24    Gabriel       Joseph 1986-05-31 09:36:05.716    Male
# 24          25    Lincoln       Brenda 1986-07-24 17:36:00.791    Male
# 29          30         Ala     Halpert 1986-11-26 10:44:22.628  Female
# 72          74      Lolita       Darci 1986-01-08 02:34:04.596  Female
# 164        165       Fadel    Bernardt 1986-05-29 00:35:58.694    Male
# 238        239     Bentley      Kippax 1986-02-11 06:22:40.734    Male
# 367        368        Vale      Olanda 1986-04-15 00:49:58.690  Female
# 373        374       Britt     Dureden 1986-11-19 23:50:47.955  Female
# 386        387   Cristabel      Chatel 1986-07-10 16:27:30.640    Male
# 415        416  Constantia       Group 1986-03-26 06:37:22.525  Female
# 452        453      Morgan   Scrowston 1986-12-19 21:34:24.472  Female
# 561        562         Dom      Baglow 1986-07-26 14:43:49.240    Male
# ...

# %% [markdown]
# #### Q.no :6 Create a pair plot by taking parameter "hue" as EDDisposition

# %%
raw_data=pd.read_excel(r'HospitalDatabase.xlsx',3)
raw_data
ax=sns.jointplot('ExpectedMortality','ExpectedLOS',data=raw_data,color='#EB984E')
# Out:
# C:\Tools\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Q.no: 7 Create a pair plot by taking parameter "hue" as EDDisposition

# %%
raw_data=pd.read_excel(r'HospitalDatabase.xlsx',6)
raw_data
ax=sns.pairplot(raw_data,plot_kws={'color':'pink'},hue='EDDisposition')

# %% [markdown]
# #### Q.no: 8 Create a bar chart between expectedLOS & Primary diagnosis

# %%
raw_data=pd.read_excel(r'HospitalDatabase.xlsx',4)
raw_data
ax=sns.barplot(x='PrimaryDiagnosis',y='ExpectedLOS',data=raw_data,ci=None).set(title='Compare')

# %% [markdown]
# #### Q.no: 9 Get the list of patient ids which are not there in ReadmissionRegistry

# %%
df1=pd.read_excel(r'HospitalDatabase.xlsx',0)
df2=pd.read_excel(r'HospitalDatabase.xlsx',3)
## check if its equals
df1.equals(df2)
df1['PatientID'].equals(df2['PatientID'])

## condition to display only uncommon rows
df = df1.merge(df2, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='left_only']
df
# Out:
#      PatientID FirstName  LastName             DateOfBirth Gender  \
# 3            4   Carmine     Texas 1968-10-15 03:32:13.635   Male
# 142        135     Cally   Aylward 1962-01-13 00:11:17.581   Male
# 152        145    Sheena       LLC 1966-10-17 13:24:21.621   Male
# 196        189    Rempel     Group 1974-07-17 04:55:39.964   Male
# 207        200      Fonz     Group 1964-01-15 01:57:57.966   Male
# ..         ...       ...       ...                     ...    ...
# 956        941       Wat   Fideler 1986-05-26 00:01:19.761   Male
# 957        942    Wandie  Baythrop 1970-06-10 21:41:03.814   Male
# 958        943   Diahann   Smeeton 1983-01-08 21:49:27.884   Male
# 959        944  Panchito   Sharple 1963-06-05 07:57:05.569   Male
# 960        945     Walsh    Calvie 1972-08-06 03:40:03.454   Male
#
#                        Race Language  AdmissionID AdmissionDate DischargeDate  \
# 3                     White  English          NaN           NaT           NaT
# ...

# %% [markdown]
# #### Q.No: 10 Create a boxplot on ExpectedLOS by taking service into account

# %%
raw_data=pd.read_excel(r'HospitalDatabase.xlsx',3)
##To increase the size of the plot
##sns.set(rc={'figure.figsize':(10,8)})

ax=sns.boxplot(x='ExpectedLOS',y='Service',data=raw_data, color='#9B59B6')

##swarmplotplot can be used to display the values
#ax=sns.swarmplot(x='ExpectedLOS',y='Service',data=raw_data, color='#F9E79F')


#Middle line is Median
#The box shows the starting of the Q1 and end of Q3
#The whiskers shows the minimum and maximum Quartile 
#Dots are outliers.

# %% [markdown]
# # Questions 21 - 30

# %%
#read excle into dataframe
df1 = pd.read_excel("HospitalDatabase.xlsx", sheet_name='Patients')

# %%
gvn_list = ['a', 'b', 'c', 'd', 'f','h']
# Calculate the length of the list using the len() function and store it in a variable.
lst_leng = len(gvn_list)
# Find the middle element of the given List by using (total length of list-1)
# divided by 2( zero indexing)and store it in a variable.
mid_vlu_odd = (lst_leng-1)//2
# Check if the given list is even or odd using the If conditional statement.
if(lst_leng % 2 == 0):
    # If the length of given list is even , get middle two elements.
    even_mid_v1 = (lst_leng-1)//2
    print(even_mid_v1)
    even_mid_v2 = (lst_leng+1)//2
    print(even_mid_v2)
    eve_res_vlu1 = gvn_list[even_mid_v1]
    eve_res_vlu2 = gvn_list[even_mid_v2]
    print('The Median of the even List of Elements =', eve_res_vlu1,eve_res_vlu2)
    
else:
    # If the length of given list is odd , Median  is the middle element.
    odd_res_vlu = gvn_list[mid_vlu_odd]
    print('The Median of the odd List of Elements =', odd_res_vlu)
# Out:
# 2
# 3
# The Median of the even List of Elements = c d

# %% [markdown]
# ### 22. Get the count of number of patients based on ReasonForVisit and EDDisposition. Use stack/unstack functions

# %%
#read excle into dataframe
df2 = pd.read_excel("HospitalDatabase.xlsx", sheet_name='EDVisits')
df2
# Out:
#       EDVisitID  PatientID               VisitDate         EDDischargeTime  \
# 0             1          1 2020-01-01 00:00:00.000 2020-01-01 11:20:22.924
# 1            12         12 2020-01-01 02:45:40.302 2020-01-02 02:00:00.517
# 2            13         13 2020-01-01 03:09:24.701 2020-01-01 05:00:20.852
# 3            14         14 2020-01-01 03:12:19.349 2020-01-01 04:32:29.142
# 4            15         15 2020-01-01 03:46:32.698 2020-01-01 06:24:52.741
# ...         ...        ...                     ...                     ...
# 1194       1183        929 2020-01-15 10:38:42.570 2020-01-16 02:31:52.023
# 1195       1186        932 2020-01-15 11:52:37.540 2020-01-16 10:19:41.570
# 1196       1187        933 2020-01-15 12:11:11.678 2020-01-15 16:41:15.223
# 1197       1188        934 2020-01-15 12:21:46.006 2020-01-15 18:32:21.060
# 1198       1189        935 2020-01-15 12:51:14.875 2020-01-15 23:40:41.456
#
#       Acuity ReasonForVisit EDDisposition
# ...

# %%
g = df2.groupby(df2.EDDisposition.str[0])['EDDisposition']
print(g)

# %%
s = df2.groupby([df2.ReasonForVisit, g.transform('last')]).size().unstack()
print(s)
# Out:
# EDDisposition        Admitted  Discharged
# ReasonForVisit
# Accident                 39.0         NaN
# Bleeding                 16.0        15.0
# Car Accident             17.0         NaN
# Chest Pain               94.0        15.0
# Cough                     NaN         1.0
# Fever                    46.0       188.0
# Gun Shot                 16.0         NaN
# Intoxication              NaN        30.0
# Laceration                NaN        30.0
# Migraine                 47.0       109.0
# Pneumonia               136.0        65.0
# Shortness of Breath      72.0        77.0
# Stomach Ache             32.0       154.0

# %% [markdown]
# ### 23 Plot a graph by counting the no. of patients in each department

# %%
#read excle into dataframe
df3 = pd.read_excel("HospitalDatabase.xlsx", sheet_name='AmbulatoryVisits')

# %%
ax = df3['VisitDepartmentID'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number of patients in each department")
ax.set_xlabel("Department Id's")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### 24. Using Arrays and Loops, find the count of of patients based on gender

# %%
#read excle into dataframe
df4 = pd.read_excel("HospitalDatabase.xlsx", sheet_name='Patients')

# %%
#the count of each of the distinct values of a specific column, you can use the pandas value_counts() function
print(df4['Gender'].value_counts())
# Out:
# Male      537
# Female    408
# Name: Gender, dtype: int64

# %% [markdown]
# ### 25. Plot a graph to count the patients based on discharge disposition

# %%
#read excle into dataframe
df5 = pd.read_excel("HospitalDatabase.xlsx", sheet_name='ReAdmissionRegistry')

# %%
dd = df5['DischargeDisposition'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number of patients in Discharge Disposition")
dd.set_xlabel("Discharge Disposition")
dd.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### 26. Which reason of visit has maximum mortality rate

# %%
#read excle into dataframe
df6 = pd.read_excel("HospitalDatabase.xlsx", sheet_name='ReAdmissionRegistry')

# %%
mortality = df6.groupby('PrimaryDiagnosis')['ExpectedMortality'].sum()
mortality
# Out:
# PrimaryDiagnosis
# AMI                   11.287028
# Afib                   3.346590
# Broken Leg             2.478958
# Diabetes              18.334439
# Fever                  5.635418
# Flu                   21.838083
# Heart Failure         30.082879
# Hip Fracture           8.586140
# Hypertension          14.827774
# Kidney Failure         4.951837
# Knee Replacement       6.678844
# Laceration             7.917630
# Migraine               6.808469
# Pain                   3.837848
# Pneumonia             66.307360
# Spinal Cord Injury     0.400558
# Stroke                30.085412
# Name: ExpectedMortality, dtype: float64

# %% [markdown]
# ### 27. Calculate average LOS

# %%
#read excle into dataframe
df7 = pd.read_excel("HospitalDatabase.xlsx", sheet_name='ReAdmissionRegistry')

# %%
#Calculate average LOS
avg_LOS = df7["ExpectedLOS"].mean()
avg_LOS
# Out:
# 8.824589159156156

# %% [markdown]
# ### 28. Which patient id has most entries in readmission registry ***

# %%
#read excle into dataframe
df8 = pd.read_excel("HospitalDatabase.xlsx", sheet_name='ReAdmissionRegistry')

# %%
val_count = df8['PatientID'].value_counts().head(1)
print(val_count)
# Out:
# 23    3
# Name: PatientID, dtype: int64

# %%
#patient ID 23 has most frequency of 3
print(df8['PatientID'].value_counts().max())
# Out:
# 3

# %% [markdown]
# ### 29. Find count of White Spanish Male ***

# %%
#read excle into dataframe
df9 = pd.read_excel("HospitalDatabase.xlsx", sheet_name='Patients')

# %%
w_s_m_count = df9.groupby('Courses')['Courses'].transform('count')
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 w_s_m_count = df9.groupby('Courses')['Courses'].transform('count')
#       2 print(df)
#
# File C:\Tools\anaconda\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
# ...

# %%
family = np.where((df9['Gender'] == 'Male', df9['Race'] == 'White', df9['Language'] == 'Spanish'))

# %%
#wsm = df9.groupby(family)['PatientID'].mean()
#print (wsm)

# %%
wsmcount=df9.groupby(family)['PatientID'].count()

# %%
c = df9.groupby(['Gender','Race','Language'])['PatientID'].count()
print(c)
# Out:
# Gender  Race                    Language
# Female  Black/African-American  English     119
#                                 Spanish      15
#         White                   English     216
#                                 Spanish      55
# Male    Black/African-American  English     306
#                                 Spanish      25
#         White                   English     186
#                                 Spanish      15
# Name: PatientID, dtype: int64

# %% [markdown]
# ### 30. Write a function to print the table of the given number

# %%
n=int(input("Enter The Number : "))

i=1

while(i<=10):
    t=n*i
    print(n,"x",i,"=",t)
    i=i+1
# Out:
# Enter The Number : 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# ### Q.no: 41 Write a regular expression to find all the digits and numbers in the string

# %%
str='I live in 2644 beacon hill ct, zip-code 48326 no-800-pack-728'
numb=re.findall('[0-9]+',str)
print(numb)
# Out:
# ['2644', '48326', '800', '728']

# %% [markdown]
# ### Q.no: 42 Which demographic patients are prone to get stroke

# %%
df=pd.read_excel(r'HospitalDatabase.xlsx',0)
df1=pd.read_excel(r'HospitalDatabase.xlsx',3)

# Merge @ DataFrames
df3 = pd.merge(df, df1, how='outer')
#Filter the result
filtered_df = df3.loc[df3['PrimaryDiagnosis'] == 'Stroke']
##Print
print(filtered_df[['Gender','Race','Language','PrimaryDiagnosis']])
# Out:
#      Gender                    Race Language PrimaryDiagnosis
# 9      Male                   White  English           Stroke
# 13     Male                   White  Spanish           Stroke
# 19     Male                   White  Spanish           Stroke
# 35   Female                   White  Spanish           Stroke
# 41   Female                   White  Spanish           Stroke
# ..      ...                     ...      ...              ...
# 615    Male  Black/African-American  English           Stroke
# 616    Male  Black/African-American  English           Stroke
# 625    Male  Black/African-American  English           Stroke
# 656  Female  Black/African-American  English           Stroke
# 686    Male                   White  English           Stroke
#
# [68 rows x 4 columns]

# %% [markdown]
# ### Q.no: 43: Create a pivot table displaying average LOS based on Service and Primary Diagnosis

# %%
df1=pd.read_excel(r'HospitalDatabase.xlsx',3)

pivot = df1.pivot_table(index =['Service', 'PrimaryDiagnosis'],values =['ExpectedLOS'], aggfunc ='mean')
print (pivot)
# Out:
#                                      ExpectedLOS
# Service          PrimaryDiagnosis
# Cardiology       AMI                   12.414202
#                  Afib                  13.162920
#                  Broken Leg             3.911826
#                  Flu                    3.970428
#                  Heart Failure         13.014044
#                  Kidney Failure         6.580273
# General Medicine Broken Leg             3.368132
#                  Diabetes               5.665298
#                  Fever                  6.803796
#                  Flu                    6.141753
#                  Hypertension           5.369365
#                  Kidney Failure         5.943163
#                  Laceration             6.771154
#                  Pneumonia              6.140270
#                  Stroke                 7.173333
# Hospitalist      AMI                   13.828290
#                  Broken Leg             7.125069
# ...

# %% [markdown]
# ### Q.no: 45: Write a code to split a sentence into words using regex

# %%
text= "pandas is a software library written for the Python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series. It is free software released under the three-clause BSD license."

# split on white-space,delimiter 
word_list = re.split(r"[-;,.\s]\s*", text)
for i in word_list :{
    print(i)}
# Out:
# pandas
# is
# a
# software
# library
# written
# for
# the
# Python
# programming
# language
# for
# data
# manipulation
# and
# analysis
# In
# particular
# it
# offers
# data
# structures
# and
# operations
# for
# manipulating
# numerical
# tables
# and
# time
# series
# It
# is
# free
# software
# released
# under
# the
# three
# clause
# BSD
# license

# %% [markdown]
# ### Q.no: 46 Create a pie chart by taking Service= ["Icu", "Neurology", "General", "Medicine"] & EcpectedLOS=[10,5,7,9] &explode the wedge with highest LOS

# %%
service=['Icu','Neurology',"General",'Medicine']
colors=['#AD1457','#D81B60','#EC407A','#F48FB1']
LOS=[10,5,7,9]
#exlpode
explode=(0.1,0,0,0)
#figuresize
plt.figure(figsize=(6,8))
#style
plt.style.use('ggplot')
#customized props
textprops = {"fontsize":15,'color':'#1F618D','fontstyle':'italic'}
plt.axis('equal')
#plot the pie
plt.pie(LOS,labels=service,explode=explode,colors=colors,autopct='%.1f%%',textprops=textprops,wedgeprops={'edgecolor':'black'},shadow=True,startangle=90)
#title
plt.title('Service over LOS',fontsize=20,color='#1A5276',fontweight='bold',fontstyle='italic')
#legend
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# ### Q.no: 47 Using indexing ,loc ,retrieve the row with maximum BloodPressureSystolic

# %%
df=pd.read_excel(r'C:\\Users\\psrip\\OneDrive\\Documents\\Tableau\\Dataset\\HospitalDatabase.xlsx',2)
df

max=df.loc[df['BloodPressureSystolic'].idxmax()]
print("ROWS WITH MAX BPSYSTOLIC:")
print(max)
# Out:
# ROWS WITH MAX BPSYSTOLIC:
# VisitID                                          933
# PatientMRN                                       884
# ProviderID                                        27
# DateofVisit                      2019-02-14 00:00:00
# DateScheduled             2019-01-22 19:26:49.163000
# VisitDepartmentID                                 12
# VisitType                               Telemedicine
# BloodPressureSystolic                          190.0
# BloodPressureDiastolic                    143.989174
# Pulse                                      74.976879
# VisitStatus                                Completed
# Name: 236, dtype: object

# %% [markdown]
# ### Q.no: 48 Display the average LOS based on Service and Discharge Disposition(Maintain the column Hierarchy)

# %%
df=pd.read_excel(r'HospitalDatabase.xlsx',3)
df
# Out:
#      AdmissionID  PatientID AdmissionDate           DischargeDate  \
# 0            389          1    2018-01-01 2018-01-04 19:59:31.391
# 1            635          2    2018-01-01 2018-01-04 21:28:51.898
# 2            606          3    2018-01-01 2018-01-04 22:28:23.672
# 3            587          5    2018-01-01 2018-01-05 05:47:04.933
# 4            640          6    2018-01-01 2018-01-05 14:18:30.029
# ..           ...        ...           ...                     ...
# 715          521        738    2018-02-22 2018-03-07 21:22:10.061
# 716          548        739    2018-02-22 2018-03-08 02:43:18.749
# 717          509        740    2018-02-22 2018-03-08 09:27:18.377
# 718          605        741    2018-02-22 2018-03-10 06:06:12.068
# 719          710        742    2018-02-22 2018-03-10 20:38:30.568
#
#     DischargeDisposition           Service PrimaryDiagnosis  ExpectedLOS  \
# 0                   Home       Hospitalist   Kidney Failure     6.717771
# ...

# %%
# using the pandas set_index() function.
df_ind3 = df.set_index(['Service', 'PrimaryDiagnosis','ExpectedLOS'])

# we can sort the data by using sort_index()
df_ind3.sort_index()

df_ind3_service = df_ind3.loc[['Cardiology','General Medicine','Hospitalist','ICU', 'Neurology','Orthopeadics']]
df_ind3_service
df.groupby(['Service', 'PrimaryDiagnosis']).ExpectedLOS.mean()
# Out:
# Service           PrimaryDiagnosis
# Cardiology        AMI                   12.414202
#                   Afib                  13.162920
#                   Broken Leg             3.911826
#                   Flu                    3.970428
#                   Heart Failure         13.014044
#                   Kidney Failure         6.580273
# General Medicine  Broken Leg             3.368132
#                   Diabetes               5.665298
#                   Fever                  6.803796
#                   Flu                    6.141753
#                   Hypertension           5.369365
#                   Kidney Failure         5.943163
#                   Laceration             6.771154
#                   Pneumonia              6.140270
#                   Stroke                 7.173333
# Hospitalist       AMI                   13.828290
#                   Broken Leg             7.125069
#                   Diabetes               7.874359
# ...

# %% [markdown]
# ### Q.no: 50: Which departmentID has maximum number of visits scheduled.

# %%
raw_data=pd.read_excel(r'HospitalDatabase.xlsx',2)

# %%
# Using groupby() and count()
raw_data = raw_data.groupby(['VisitDepartmentID'])['VisitDepartmentID'].count().nlargest()
print("DepartmentID with max visits")
raw_data.head(1)
# Out:
# DepartmentID with max visits
# VisitDepartmentID
# 11    102
# Name: VisitDepartmentID, dtype: int64
